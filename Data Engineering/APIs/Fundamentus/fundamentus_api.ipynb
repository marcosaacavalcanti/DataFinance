# %% [markdown]
# # Fundamentus

# %% [markdown]
# ### Links

# %% [markdown]
# https://www.fundamentus.com.br/index.php
#
# https://pypi.org/project/fundamentus/

# %% [markdown]
# ### Install Libraries

# %%
# !pip install fundamentus

import fundamentus
import pandas as pd
# Out:
# ...
# 2022-12-26 21:22:54,095 [logging.log_init] INFO: LOGLEVEL=INFO

# %% [markdown]
# ### Exploring the API

# %% [markdown]
# #### Raw Data

# %%
data = fundamentus.get_resultado_raw()
data
# Out:
# Multiples  Cotação     P/L  P/VP    PSR  Div.Yield  P/Ativo  P/Cap.Giro  \
# papel
# AALR3        21.20  -18.51  2.34  2.296     0.0000    0.953      -30.57
# ABCB3         0.00    0.00  0.00  0.000     0.0000    0.000        0.00
# ABCB4        19.54    5.79  0.87  0.000     0.0655    0.000        0.00
# ABEV3        14.52   17.46  2.54  2.894     0.0525    1.610       34.77
# ABYA3         4.91 -214.80  1.76  2.055     0.0000    0.527        1.98
# ...            ...     ...   ...    ...        ...      ...         ...
# WLMM4        21.76    6.99  1.31  0.445     0.0475    1.073        2.55
# WMBY3        25.39  -19.30  2.87  0.836     0.0000    0.182        1.20
# WSON33       67.00    8.07  0.98  1.067     0.0000    0.400       13.41
# YDUQ3        10.19  -66.49  1.04  0.698     0.0124    0.317        2.12
# ZAMP3         5.48  -20.35  1.04  0.430     0.0000    0.378       10.28
#
# Multiples  P/EBIT  P/Ativ Circ.Liq  EV/EBIT  EV/EBITDA  Mrg Ebit  Mrg. Líq.  \
# papel
# ...

# %%
data.dtypes
# Out:
# Multiples
# Cotação              float64
# P/L                  float64
# P/VP                 float64
# PSR                  float64
# Div.Yield            float64
# P/Ativo              float64
# P/Cap.Giro           float64
# P/EBIT               float64
# P/Ativ Circ.Liq      float64
# EV/EBIT              float64
# EV/EBITDA            float64
# Mrg Ebit             float64
# Mrg. Líq.            float64
# Liq. Corr.           float64
# ROIC                 float64
# ROE                  float64
# Liq.2meses           float64
# Patrim. Líq          float64
# Dív.Brut/ Patrim.    float64
# Cresc. Rec.5a        float64
# dtype: object

# %%
data.describe()
# Out:
# Multiples       Cotação          P/L           P/VP            PSR  \
# count        987.000000    987.00000     987.000000     987.000000
# mean          59.065451     75.62924    1463.028713     141.305340
# std          479.075562   2123.84429   31879.355812    4028.658888
# min            0.000000  -3584.82000    -228.000000     -20.054000
# 25%            3.885000     -0.15000       0.120000       0.049500
# 50%           10.900000      4.20000       1.020000       0.585000
# 75%           27.670000     12.18000       1.975000       1.687500
# max        10081.900000  66496.50000  723708.000000  126505.000000
#
# Multiples   Div.Yield     P/Ativo    P/Cap.Giro       P/EBIT  P/Ativ Circ.Liq  \
# count      987.000000  987.000000    987.000000   987.000000       987.000000
# mean         0.035495    1.956318     22.743911   -14.856039        -1.635491
# std          0.202989   23.757125   1241.582156   283.383934        31.508849
# ...

# %%
data[(data["P/L"] > 0) & (data["P/L"] < 15)]
# Out:
# Multiples   Cotação    P/L    P/VP    PSR  Div.Yield  P/Ativo  P/Cap.Giro  \
# papel
# ABCB4         19.54   5.79    0.87  0.000     0.0655    0.000        0.00
# ACES3         95.27   8.79    2.28  1.693     0.0000    1.438        6.40
# ACES4         94.73   8.74    2.27  1.683     0.0000    1.430        6.37
# AELP3          1.93   8.49 -200.57 -0.062     0.0000    5.216        0.00
# AESL3      10081.90  10.90    2.94  1.084     0.0000    0.726      734.54
# ...             ...    ...     ...    ...        ...      ...         ...
# WHRL4          5.00  13.88    3.08  0.687     0.0412    0.928       14.54
# WIZS3          6.97   7.14    2.57  1.272     0.0844    0.560      -11.64
# WLMM3         21.50   6.90    1.29  0.439     0.0437    1.060        2.52
# WLMM4         21.76   6.99    1.31  0.445     0.0475    1.073        2.55
# WSON33        67.00   8.07    0.98  1.067     0.0000    0.400       13.41
#
# ...

# %% [markdown]
# #### Get Stocks

# %%
data = fundamentus.get_papel(["ITSA4","WEGE3"])
data
# Out:
# 2022-12-26 21:23:16,351 [detalhes.get_papel] INFO: detalhes: call: get..._list()
# 2022-12-26 21:23:16,352 [detalhes.get_detalhes_list] INFO: get list: [Papel: ITSA4]
# 2022-12-26 21:23:16,418 [detalhes.get_detalhes_list] INFO: get list: [Papel: WEGE3]
#         Tipo       Empresa                       Setor  \
# ITSA4  PN N1  ITAÚSA PN N1  Intermediários Financeiros
# WEGE3  ON N1  WEG SA ON N1     Máquinas e Equipamentos
#
#                              Subsetor Cotacao Data_ult_cot Min_52_sem  \
# ITSA4                          Bancos    8.47   2022-12-26       7.12
# WEGE3  Motores, Compressores e Outros   38.19   2022-12-26      22.63
#
#       Max_52_sem Vol_med_2m  Valor_de_mercado  ...  Ativo_Circulante  \
# ITSA4       9.63  275484000       82170900000  ...       11187000000
# WEGE3      40.85  334163000      160296000000  ...       19548400000
#
#          Div_Bruta Div_Liquida   Patrim_Liq Receita_Liquida_12m    EBIT_12m  \
# ...

# %% [markdown]
# #### Get Sectors

# %% [markdown]
# https://github.com/mv/fundamentus/blob/1cab1cf965d99c02d05faa90807ebe7381cbc784/src/fundamentus/setor.py#L56

# %%
agribusiness = fundamentus.list_papel_setor(1)  # agribusiness
energy = fundamentus.list_papel_setor(14)     # energy

print(agribusiness)
print(energy)
# Out:
# ['AGXY3', 'FRTA3', 'AGRO3', 'SLCE3', 'TTEN3', 'SOJA3']
# ['AESB3', 'CBEE3', 'LIGT3', 'RNEW3', 'RNEW4', 'RNEW11', 'CLSC3', 'CEBR6', 'CEBR3', 'CEBR5', 'CLSC4', 'GPAR3', 'NEOE3', 'AFLT3', 'CEEB5', 'ENBR3', 'EKTR3', 'TRPL4', 'CSRN5', 'CEEB3', 'ENGI4', 'TAEE11', 'TAEE3', 'TAEE4', 'COCE5', 'EKTR4', 'CMIG4', 'EQMA3B', 'CSRN6', 'CSRN3', 'CPFE3', 'REDE3', 'ENGI11', 'TRPL3', 'ALUP3', 'ALUP11', 'ALUP4', 'CEED4', 'CMIG3', 'CEED3', 'EQPA3', 'ENGI3', 'EQPA7', 'EQTL3', 'MEGA3', 'EQPA5', 'ENMT4', 'ENMT3', 'GEPA3', 'GEPA4', 'EGIE3', 'ENEV3', 'CPLE3', 'ELET3', 'ELET6', 'CPLE11', 'EMAE4', 'CPLE6', 'LIPR3', 'CEPE5', 'AURE3', 'CPLE5']
